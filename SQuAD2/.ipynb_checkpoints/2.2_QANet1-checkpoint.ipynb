# %% [markdown]
# # Homework 5: Machine Reading

# %% [markdown]
# ## 1. Random QA

# %% [markdown]
# 1) What is the probability $p_{k,n}$ that our random QA system will output an answer with $k$ tokens when given a context paragraph with $n$ token as input?

# %% [markdown]
# 2) For a fixed $n$ of $100$, produce a plot of $p_{k,n}$ and $\hat{p}_{k,n}$  vs $k$. Design a monte-carlo experiment to estimate the values for $\hat{p}_{k,n}$.

# %% [markdown]
# 3) Calculate the expected length of the answer given by your random QA system. i,e write an expression for $L_n = E[K]$ (It's fine to leave it as a summation).

# %% [markdown]
# $$ L_n = $$

# %% [markdown]
# 4) Plot $\hat{L_n}$ estimated through monte-carlo simulations and $L_n$ for $n = 5, 10, 25, 50, 100, 250$ and $500$.

# %% [markdown]
# 5) Calculate the probability, $p_n$ that Random QA system outputs the correct answer to your question.

# %% [markdown]
# $$p_n = $$

# %% [markdown]
# 6)  In SQuAD 2.0 data set, the answer for your question can either lie within the context paragraph or there could be no answer within the given paragraph. Let $\alpha$ represent the fraction of questions for which the answer \textbf{does not} lie within the paragraph.

# %% [markdown]
# ## RNN Based Model

# %% [markdown]
# ### 2.1.1 Diagram of Baseline

# %% [markdown]
# ### 2.1.2 Performance of Baseline

# %%
### code to load your model and evaluate on the dev set

### model = 

def evaluate_on_dev_set(model, devloader):
    return f1_score, em_score

# %% [markdown]
# ##### F1 Score on Dev Set:
# ##### EM on Dev Set:

# %% [markdown]
# ## Improving the Baseline

# %% [markdown]
# ### 2.2.1 Diagram of your architecture

# %% [markdown]
# reference: https://arxiv.org/pdf/1804.09541.pdf
#            https://github.com/BangLiu/QANet-PyTorch

# %%
from IPython.display import Image
Image('QANet.png')

# %%
# !pip install visdom
# Out:
# Collecting visdom
#   Downloading https://files.pythonhosted.org/packages/c9/75/e078f5a2e1df7e0d3044749089fc2823e62d029cc027ed8ae5d71fafcbdc/visdom-0.1.8.9.tar.gz (676kB)
#      |████████████████████████████████| 686kB 3.0MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.8 in ./anaconda3/lib/python3.7/site-packages (from visdom) (1.17.2)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.7/site-packages (from visdom) (1.3.1)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.7/site-packages (from visdom) (2.22.0)
# Requirement already satisfied: tornado in ./anaconda3/lib/python3.7/site-packages (from visdom) (6.0.3)
# Requirement already satisfied: pyzmq in ./anaconda3/lib/python3.7/site-packages (from visdom) (18.1.0)
# Requirement already satisfied: six in ./anaconda3/lib/python3.7/site-packages (from visdom) (1.12.0)
# Collecting jsonpatch (from visdom)
#   Downloading https://files.pythonhosted.org/packages/86/7e/035d19a73306278673039f0805b863be8798057cc1b4008b9c8c7d1d32a3/jsonpatch-1.24-py2.py3-none-any.whl
# Collecting torchfile (from visdom)
#   Downloading https://files.pythonhosted.org/packages/91/af/5b305f86f2d218091af657ddb53f984ecbd9518ca9fe8ef4103a007252c9/torchfile-0.1.0.tar.gz
# Collecting websocket-client (from visdom)
#   Downloading https://files.pythonhosted.org/packages/29/19/44753eab1fdb50770ac69605527e8859468f3c0fd7dc5a76dd9c4dbd7906/websocket_client-0.56.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 66.1MB/s eta 0:00:01
# Requirement already satisfied: pillow in ./anaconda3/lib/python3.7/site-packages (from visdom) (6.2.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.7/site-packages (from requests->visdom) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in ./anaconda3/lib/python3.7/site-packages (from requests->visdom) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.7/site-packages (from requests->visdom) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./anaconda3/lib/python3.7/site-packages (from requests->visdom) (1.24.2)
# Collecting jsonpointer>=1.9 (from jsonpatch->visdom)
#   Downloading https://files.pythonhosted.org/packages/18/b0/a80d29577c08eea401659254dfaed87f1af45272899e1812d7e01b679bc5/jsonpointer-2.0-py2.py3-none-any.whl
# Building wheels for collected packages: visdom, torchfile
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp37-none-any.whl size=655252 sha256=4f7255b622179f4ecd0971d580f6bfc6e6a81ef792e267a2e84e63c7cc3e0909
#   Stored in directory: /home/lz1883/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
#   Building wheel for torchfile (setup.py) ... done
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp37-none-any.whl size=5712 sha256=5daa3df1ef319125a38d8a9507fd344040e6cb8c83563302a8ab4657e46b8f57
#   Stored in directory: /home/lz1883/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# Installing collected packages: jsonpointer, jsonpatch, torchfile, websocket-client, visdom
# Successfully installed jsonpatch-1.24 jsonpointer-2.0 torchfile-0.1.0 visdom-0.1.8.9 websocket-client-0.56.0

# %%
# !cd QANet-PyTorch && python3 QANet_main.py -h
# Out:
# usage: QANet_main.py [-h] [--processed_data] [--train_file TRAIN_FILE]
#                      [--dev_file DEV_FILE]
#                      [--train_examples_file TRAIN_EXAMPLES_FILE]
#                      [--dev_examples_file DEV_EXAMPLES_FILE]
#                      [--train_meta_file TRAIN_META_FILE]
#                      [--dev_meta_file DEV_META_FILE]
#                      [--train_eval_file TRAIN_EVAL_FILE]
#                      [--dev_eval_file DEV_EVAL_FILE]
#                      [--val_num_batches VAL_NUM_BATCHES]
#                      [--glove_word_file GLOVE_WORD_FILE]
#                      [--glove_word_size GLOVE_WORD_SIZE]
#                      [--glove_dim GLOVE_DIM] [--word_emb_file WORD_EMB_FILE]
#                      [--word_dictionary WORD_DICTIONARY] [--pretrained_char]
#                      [--char_dim CHAR_DIM] [--char_emb_file CHAR_EMB_FILE]
#                      [--char_dictionary CHAR_DICTIONARY] [-b BATCH_SIZE]
#                      [-e EPOCHS] [--debug] [--debug_batchnum DEBUG_BATCHNUM]
#                      [--resume RESUME] [--verbosity VERBOSITY]
#                      [--save_dir SAVE_DIR] [--save_freq SAVE_FREQ]
#                      [--print_freq PRINT_FREQ] [--with_cuda] [--multi_gpu]
#                      [--visualizer] [--log_file LOG_FILE] [--lr LR]
#                      [--lr_warm_up_num LR_WARM_UP_NUM] [--beta1 BETA1]
#                      [--beta2 BETA2] [--decay DECAY] [--use_scheduler]
#                      [--use_grad_clip] [--grad_clip GRAD_CLIP] [--use_ema]
#                      [--use_early_stop] [--early_stop EARLY_STOP]
#                      [--para_limit PARA_LIMIT] [--ques_limit QUES_LIMIT]
#                      [--ans_limit ANS_LIMIT] [--char_limit CHAR_LIMIT]
#                      [--d_model D_MODEL] [--num_head NUM_HEAD]
#
# Lucy
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --processed_data      whether the dataset already processed
#   --train_file TRAIN_FILE
#                         path of train dataset
#   --dev_file DEV_FILE   path of dev dataset
#   --train_examples_file TRAIN_EXAMPLES_FILE
#                         path of train dataset examples file
#   --dev_examples_file DEV_EXAMPLES_FILE
#                         path of dev dataset examples file
#   --train_meta_file TRAIN_META_FILE
#                         path of train dataset meta file
#   --dev_meta_file DEV_META_FILE
#                         path of dev dataset meta file
#   --train_eval_file TRAIN_EVAL_FILE
#                         path of train dataset eval file
#   --dev_eval_file DEV_EVAL_FILE
#                         path of dev dataset eval file
#   --val_num_batches VAL_NUM_BATCHES
#                         number of batches for evaluation (default: 500)
#   --glove_word_file GLOVE_WORD_FILE
#                         path of word embedding file
#   --glove_word_size GLOVE_WORD_SIZE
#                         Corpus size for Glove
#   --glove_dim GLOVE_DIM
#                         word embedding size (default: 300)
#   --word_emb_file WORD_EMB_FILE
#                         path of word embedding matrix file
#   --word_dictionary WORD_DICTIONARY
#                         path of word embedding dict file
#   --pretrained_char     whether train char embedding or not
#   --char_dim CHAR_DIM   char embedding size (default: 64)
#   --char_emb_file CHAR_EMB_FILE
#                         path of char embedding matrix file
#   --char_dictionary CHAR_DICTIONARY
#                         path of char embedding dict file
#   -b BATCH_SIZE, --batch_size BATCH_SIZE
#                         mini-batch size (default: 32)
#   -e EPOCHS, --epochs EPOCHS
#                         number of total epochs (default: 30)
#   --debug               debug mode or not
#   --debug_batchnum DEBUG_BATCHNUM
#                         only train and test a few batches when debug (devault:
#                         2)
#   --resume RESUME       path to latest checkpoint (default: none)
#   --verbosity VERBOSITY
#                         verbosity, 0: quiet, 1: per epoch, 2: complete
#                         (default: 2)
#   --save_dir SAVE_DIR   directory of saved model (default: checkpoints/)
#   --save_freq SAVE_FREQ
#                         training checkpoint frequency (default: 1 epoch)
#   --print_freq PRINT_FREQ
#                         print training information frequency (default: 10
#                         steps)
#   --with_cuda           use CPU in case there's no GPU support
#   --multi_gpu           use multi-GPU in case there's multiple GPUs available
#   --visualizer          use visdom visualizer or not
#   --log_file LOG_FILE   path of log file
#   --lr LR               learning rate
#   --lr_warm_up_num LR_WARM_UP_NUM
#                         number of warm-up steps of learning rate
#   --beta1 BETA1         beta 1
#   --beta2 BETA2         beta 2
#   --decay DECAY         exponential moving average decay
#   --use_scheduler       whether use learning rate scheduler
#   --use_grad_clip       whether use gradient clip
#   --grad_clip GRAD_CLIP
#                         global Norm gradient clipping rate
#   --use_ema             whether use exponential moving average
#   --use_early_stop      whether use early stop
#   --early_stop EARLY_STOP
#                         checkpoints for early stop
#   --para_limit PARA_LIMIT
#                         maximum context token number
#   --ques_limit QUES_LIMIT
#                         maximum question token number
#   --ans_limit ANS_LIMIT
#                         maximum answer token number
#   --char_limit CHAR_LIMIT
#                         maximum char number in a word
#   --d_model D_MODEL     model hidden size
#   --num_head NUM_HEAD   attention num head

# %%
# !cd QANet-PyTorch && python3 QANet_main.py --batch_size 8 --epochs 10 --with_cuda --use_ema --resume "./checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar"
# Out:
# Namespace(ans_limit=30, batch_size=8, beta1=0.8, beta2=0.999, char_dictionary='./datasets/char_dict.pkl', char_dim=64, char_emb_file='./datasets/char_emb.pkl', char_limit=16, d_model=128, debug=False, debug_batchnum=2, decay=0.9999, dev_eval_file='./datasets/dev-v2.0-eval.pkl', dev_examples_file='./datasets/dev-v2.0-examples.pkl', dev_file='./datasets/dev-v2.0.json', dev_meta_file='./datasets/dev-v2.0-meta.pkl', early_stop=10, epochs=10, glove_dim=300, glove_word_file='./datasets/Glove/glove.840B.300d.txt', glove_word_size=2200000, grad_clip=5.0, log_file='log.txt', lr=0.001, lr_warm_up_num=1000, multi_gpu=False, num_head=8, para_limit=400, pretrained_char=False, print_freq=1000, processed_data=False, ques_limit=50, resume='./checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar', save_dir='checkpoints/', save_freq=1, train_eval_file='./datasets/train-v2.0-eval.pkl', train_examples_file='./datasets/train-v2.0-examples.pkl', train_file='./datasets/train-v2.0.json', train_meta_file='./datasets/train-v2.0-meta.pkl', use_early_stop=True, use_ema=True, use_grad_clip=True, use_scheduler=True, val_num_batches=500, verbosity=2, visualizer=False, with_cuda=True, word_dictionary='./datasets/word_dict.pkl', word_emb_file='./datasets/word_emb.pkl')
# device is cuda, # cuda is:  1
# Generating train examples...
# <class 'str'>
# 100%|█████████████████████████████████████████| 442/442 [00:58<00:00,  7.59it/s]
# 130319 questions in total
# Generating dev examples...
# <class 'str'>
# 100%|███████████████████████████████████████████| 16/16 [00:03<00:00,  4.07it/s]
# 6078 questions in total
# Generating word embedding...
# 100%|█████████████████████████████▉| 2196018/2200000 [03:02<00:00, 12014.86it/s]
# 90256 / 109596 tokens have corresponding word embedding vector
# Generating char embedding...
# 1416 tokens have corresponding embedding vector
# Processing train examples...
# 100%|█████████████████████████████████| 130319/130319 [00:59<00:00, 2182.66it/s]
# Built 129907 / 130319 instances of features in total
# Processing dev examples...
# 100%|█████████████████████████████████████| 6078/6078 [00:02<00:00, 2107.81it/s]
# Built 5951 / 6078 instances of features in total
# Saving word embedding...
# Saving char embedding...
# Saving word dictionary...
# Saving char dictionary...
# Saving train examples...
# Saving dev examples...
# Saving train meta...
# Saving dev meta...
# Saving train eval...
# Saving dev eval...
# Trainable parameters: 1295113
# Loading checkpoint: ./checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar ...
# Checkpoint './checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar' (epoch 9) loaded
# /home/lz1883/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# step: 84/16239 	 epoch: 9 	 lr: [0.0006577092845332328] 	 loss: 3.39492230275098 	 speed: 16.364102593613957 examples/sec
# step: 1084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.553264694571495 	 speed: 16.44824441722012 examples/sec
# step: 2084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.6935197949409484 	 speed: 16.43350586419834 examples/sec
# step: 3084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.763116829037666 	 speed: 16.441632264310556 examples/sec
# step: 4084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.810349919080734 	 speed: 16.44354709417125 examples/sec
# step: 5084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.8040878903865813 	 speed: 16.469955079121917 examples/sec
# step: 6084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.7421510663032533 	 speed: 16.48215246535975 examples/sec
# step: 7084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.8514171256422998 	 speed: 16.521482077155927 examples/sec
# step: 8084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.869610175669193 	 speed: 16.492800070729086 examples/sec
# step: 9084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.8210209856629374 	 speed: 16.421728005993675 examples/sec
# step: 10084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.909619343161583 	 speed: 16.414841443231712 examples/sec
# step: 11084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.850556255578995 	 speed: 16.402432946825037 examples/sec
# step: 12084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.7779038096666335 	 speed: 16.41626878141064 examples/sec
# step: 13084/16239 	 epoch: 9 	 lr: [0.001] 	 loss: 3.978792216897011 	 speed: 16.240146558054782 examples/sec
# ^C

# %%
# !md5sum "QANet-PyTorch/checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar"
# Out:
# 5ed0d6dc9eab261a0523184198ac8e01  QANet-PyTorch/checkpoints/QANet_checkpoint_epoch08_f1_63.09579_em_49.15000.pth.tar

# %% [markdown]
# ### 2.2.2 Performance of your Architecture

# %%
## load your saved model

# evaluate_on_dev_set(your_model, dev_set)

# %% [markdown]
# ##### F1 Score on Dev Set:
# ##### EM on Dev Set:

# %% [markdown]
# ## 3 Fine Tuning Bert

# %%
## load your saved model

# evaluate_on_dev_set(your_bert_model, dev_set)

# %% [markdown]
# ##### F1 Score on Dev Set:
# ##### EM on Dev Set:

# %% [markdown]
# ## 4 Analysis

# %% [markdown]
# Example 1
#
# Example 2
#
# Example 3
